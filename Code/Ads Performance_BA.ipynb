# %% [markdown]
# # 2024

# %% [markdown]
# ## US MARKET

# %%
import pandas as pd
import os
import sys
import re

import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from google.oauth2.service_account import Credentials

# %%
# Đường dẫn thư mục chứa các file CSV
folder_path = "US/BA_US/2024"

# Danh sách các file CSV
file_names = [
    "US_Quarter 1_2024.csv",
    "US_Quarter 2_2024.csv",
    "US_Quarter 3_2024.csv",
    "US_Quarter 4_2024.csv"
]

# Danh sách để chứa các dataframe sau khi đọc
dfs = []

for file in file_names:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path, skiprows=1)

    # Chuyển Reporting Date sang datetime
    df["Reporting Date"] = pd.to_datetime(df["Reporting Date"], errors="coerce")

    # Tính quarter từ Reporting Date
    df["quarter"] = df["Reporting Date"].dt.quarter

    dfs.append(df)

# Gộp tất cả lại
merged_df = pd.concat(dfs, ignore_index=True)

# %%
scopes = ["https://www.googleapis.com/auth/spreadsheets", 
          "https://www.googleapis.com/auth/drive"]
creds = Credentials.from_service_account_file("/Users/thuytrinh/Downloads/new_credential.json", scopes=scopes)
client = gspread.authorize(creds)

# Mở Google Sheet
sheet_id = "1p3JWtN9HH1HxvARmx34Tmbt2iAjoYhK9fWIHgQr4PDE"

# Mở file Google Sheet (Spreadsheet object)
spreadsheet = client.open_by_key(sheet_id)
sheet1 = client.open_by_key(sheet_id).worksheet("BA_US_2024")

set_with_dataframe(sheet1, merged_df)

# %% [markdown]
# ## CA MARKET

# %%
import pandas as pd
import os
import sys
import re

import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from google.oauth2.service_account import Credentials

# %%
# Đường dẫn thư mục chứa các file CSV
folder_path = "CA/BA_CA/2024"

# Danh sách các file CSV
file_names = [
    "CA_Quarter 1_2024.csv",
    "CA_Quarter 2_2024.csv",
    "CA_Quarter 3_2024.csv",
    "CA_Quarter 4_2024.csv"
]

# Danh sách để chứa các dataframe sau khi đọc
dfs = []

for file in file_names:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path, skiprows=1)

    # Chuyển Reporting Date sang datetime
    df["Reporting Date"] = pd.to_datetime(df["Reporting Date"], errors="coerce")

    # Tính quarter từ Reporting Date
    df["quarter"] = df["Reporting Date"].dt.quarter

    dfs.append(df)

# Gộp tất cả lại
merged_df = pd.concat(dfs, ignore_index=True)

# %%
scopes = ["https://www.googleapis.com/auth/spreadsheets", 
          "https://www.googleapis.com/auth/drive"]
creds = Credentials.from_service_account_file("/Users/thuytrinh/Downloads/new_credential.json", scopes=scopes)
client = gspread.authorize(creds)

# Mở Google Sheet
sheet_id = "1p3JWtN9HH1HxvARmx34Tmbt2iAjoYhK9fWIHgQr4PDE"

# Mở file Google Sheet (Spreadsheet object)
spreadsheet = client.open_by_key(sheet_id)
sheet1 = client.open_by_key(sheet_id).worksheet("BA_CA_2024")

set_with_dataframe(sheet1, merged_df)

# %% [markdown]
# ## UK MARKET

# %%
import pandas as pd
import os
import sys
import re

import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from google.oauth2.service_account import Credentials

# %%
# Đường dẫn thư mục chứa các file CSV
folder_path = "UK/BA_UK/2024"

# Danh sách các file CSV
file_names = [
    "GB_Quarter 1_2024.csv",
    "GB_Quarter 2_2024.csv",
    "GB_Quarter 3_2024.csv",
    "GB_Quarter 4_2024.csv"
]

# Danh sách để chứa các dataframe sau khi đọc
dfs = []

for file in file_names:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path, skiprows=1)

    # Chuyển Reporting Date sang datetime
    df["Reporting Date"] = pd.to_datetime(df["Reporting Date"], errors="coerce")

    # Tính quarter từ Reporting Date
    df["quarter"] = df["Reporting Date"].dt.quarter

    dfs.append(df)

# Gộp tất cả lại
merged_df = pd.concat(dfs, ignore_index=True)

# %%
scopes = ["https://www.googleapis.com/auth/spreadsheets", 
          "https://www.googleapis.com/auth/drive"]
creds = Credentials.from_service_account_file("/Users/thuytrinh/Downloads/new_credential.json", scopes=scopes)
client = gspread.authorize(creds)

# Mở Google Sheet
sheet_id = "1p3JWtN9HH1HxvARmx34Tmbt2iAjoYhK9fWIHgQr4PDE"

# Mở file Google Sheet (Spreadsheet object)
spreadsheet = client.open_by_key(sheet_id)
sheet1 = client.open_by_key(sheet_id).worksheet("BA_UK_2024")

set_with_dataframe(sheet1, merged_df)

# %% [markdown]
# # 2025

# %% [markdown]
# ## US MARKET

# %%
import pandas as pd
import os
import sys
import re

import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from google.oauth2.service_account import Credentials

# %%
# ASIN Title, ASIN, Category, Impressions: Impressions, Clicks: Clicks, Clicks: Click Rate (CTR), Cart Adds: Cart Adds, Purchases: Purchases, Purchases: Search Traffic Sales, Purchases: Conversion Rate %, Reporting Date

# Thư mục chứa dữ liệu
folder_path = "US/BA_US/2025"

# Tên file các tháng 4, 5, 6
monthly_files = [
    "US_Month 4_2025.csv",
    "US_Month 5_2025.csv",
    "US_Month 6_2025.csv"
]

# Các cột cần lấy
selected_columns = [
    "ASIN Title", "ASIN", "Category",
    "Impressions: Impressions", "Clicks: Clicks", "Clicks: Click Rate (CTR)",
    "Cart Adds: Cart Adds", "Purchases: Purchases",
    "Purchases: Search Traffic Sales", "Purchases: Conversion Rate %"
]

# Đọc và lọc dữ liệu từng tháng
dfs = []
for file in monthly_files:
    path = os.path.join(folder_path, file)
    df = pd.read_csv(path, skiprows=1)  # Nếu có dòng đầu để bỏ
    df = df[selected_columns]
    dfs.append(df)

# Gộp 3 tháng
merged_months = pd.concat(dfs, ignore_index=True)

# Tính toán: groupby và tính toán tương ứng
agg_dict = {
    "Impressions: Impressions": "sum",
    "Clicks: Clicks": "sum",
    "Clicks: Click Rate (CTR)": "mean",
    "Cart Adds: Cart Adds": "sum",
    "Purchases: Purchases": "sum",
    "Purchases: Search Traffic Sales": "sum",
    "Purchases: Conversion Rate %": "mean"
}

monthly_summary = merged_months.groupby(["ASIN Title", "ASIN", "Category"], as_index=False).agg(agg_dict)

# Gán ngày cuối quý 2
monthly_summary["Reporting Date"] = pd.to_datetime("2025-06-30")

# Đọc dữ liệu quý 1
q1_file = os.path.join(folder_path, "US_Quarter 1_2025.csv")
q1_df = pd.read_csv(q1_file, skiprows=1)
q1_df = q1_df[selected_columns]
q1_df["Reporting Date"] = pd.to_datetime("2025-03-31")

# Gộp dữ liệu Q1 và tổng hợp tháng 4-6
final_df = pd.concat([q1_df, monthly_summary], ignore_index=True)

# Convert Reporting Date và tạo cột quarter từ đó
final_df["Reporting Date"] = pd.to_datetime(final_df["Reporting Date"])
final_df["Quarter"] = final_df["Reporting Date"].dt.quarter

# Hiển thị kết quả
final_df.tail()
# Out:
#                                             ASIN Title        ASIN Category  \
# 859  NewEleven for Mom - Gifts for Mama Birthday, C...  B0DLV94K7D     Home
# 860  NewEleven for Mom, Mama Gifts, Birthday Gifts ...  B0DJZ1LW8L     Home
# 861  NewEleven for Mom, New Mom - Gifts for a Mom o...  B0DNSVCL7J     Home
# 862  NewEleven for Women, Friend Gifts for Women, f...  B0DK14C5XC     Home
# 863  Neweleven Replacement Lid For 20 Oz NewEleven ...  B0995JRMHP  Kitchen
#
#      Impressions: Impressions  Clicks: Clicks  Clicks: Click Rate (CTR)  \
# 859                      3374              28                  1.006667
# 860                     12925             164                  1.283333
# 861                       164               0                  0.000000
# 862                      1355               5                  0.333333
# 863                      1863              62                  3.973333
#
#      Cart Adds: Cart Adds  Purchases: Purchases  \
# 859                    11                     5
# 860                    60                    17
# 861                     0                     0
# 862                     0                     0
# 863                    41                    27
#
#      Purchases: Search Traffic Sales  Purchases: Conversion Rate %  \
# 859                            48.93                     17.423333
# 860                           159.95                     14.230000
# 861                             0.00                           NaN
# 862                             0.00                      0.000000
# 863                           279.44                     42.823333
#
#     Reporting Date  Quarter
# 859     2025-06-30        2
# 860     2025-06-30        2
# 861     2025-06-30        2
# 862     2025-06-30        2
# 863     2025-06-30        2

# %%
scopes = ["https://www.googleapis.com/auth/spreadsheets", 
          "https://www.googleapis.com/auth/drive"]
creds = Credentials.from_service_account_file("/Users/thuytrinh/Downloads/new_credential.json", scopes=scopes)
client = gspread.authorize(creds)

# Mở Google Sheet
sheet_id = "1p3JWtN9HH1HxvARmx34Tmbt2iAjoYhK9fWIHgQr4PDE"

# Mở file Google Sheet (Spreadsheet object)
spreadsheet = client.open_by_key(sheet_id)
sheet1 = client.open_by_key(sheet_id).worksheet("BA_US_2025")

set_with_dataframe(sheet1, final_df)

# %% [markdown]
# ## CA MARKET

# %%
import pandas as pd
import os
import sys
import re

import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from google.oauth2.service_account import Credentials

# %%
# ASIN Title, ASIN, Category, Impressions: Impressions, Clicks: Clicks, Clicks: Click Rate (CTR), Cart Adds: Cart Adds, Purchases: Purchases, Purchases: Search Traffic Sales, Purchases: Conversion Rate %, Reporting Date

# Thư mục chứa dữ liệu
folder_path = "CA/BA_CA/2025"

# Tên file các tháng 4, 5, 6
monthly_files = [
    "CA_Month 4_2025.csv",
    "CA_Month 5_2025.csv",
    "CA_Month 6_2025.csv"
]

# Các cột cần lấy
selected_columns = [
    "ASIN title", "ASIN", "Category",
    "Impressions: Impressions", "Clicks: Clicks", "Clicks: Click Rate (CTR)",
    "Cart Adds: Cart Adds", "Purchases: Purchases",
    "Purchases: Search Traffic Sales", "Purchases: Conversion Rate %"
]

# Đọc và lọc dữ liệu từng tháng
dfs = []
for file in monthly_files:
    path = os.path.join(folder_path, file)
    df = pd.read_csv(path, skiprows=1)  # Nếu có dòng đầu để bỏ
    df = df[selected_columns]
    dfs.append(df)

# Gộp 3 tháng
merged_months = pd.concat(dfs, ignore_index=True)

# Tính toán: groupby và tính toán tương ứng
agg_dict = {
    "Impressions: Impressions": "sum",
    "Clicks: Clicks": "sum",
    "Clicks: Click Rate (CTR)": "mean",
    "Cart Adds: Cart Adds": "sum",
    "Purchases: Purchases": "sum",
    "Purchases: Search Traffic Sales": "sum",
    "Purchases: Conversion Rate %": "mean"
}

monthly_summary = merged_months.groupby(["ASIN title", "ASIN", "Category"], as_index=False).agg(agg_dict)

# Gán ngày cuối quý 2
monthly_summary["Reporting Date"] = pd.to_datetime("2025-06-30")

# Đọc dữ liệu quý 1
q1_file = os.path.join(folder_path, "CA_Quarter 1_2025.csv")
q1_df = pd.read_csv(q1_file, skiprows=1)
q1_df = q1_df[selected_columns]
q1_df["Reporting Date"] = pd.to_datetime("2025-03-31")

# Gộp dữ liệu Q1 và tổng hợp tháng 4-6
final_df = pd.concat([q1_df, monthly_summary], ignore_index=True)

# Convert Reporting Date và tạo cột quarter từ đó
final_df["Reporting Date"] = pd.to_datetime(final_df["Reporting Date"])
final_df["Quarter"] = final_df["Reporting Date"].dt.quarter

# Hiển thị kết quả
final_df.tail()
# Out:
#                                             ASIN title        ASIN Category  \
# 518  Replacement Lid For 20 Oz NewEleven Tumbler - ...  B0995JRMHP     Home
# 519  Retirement Gifts For Men Women 2023 - Retired ...  B0C3CW184G  Kitchen
# 520  Retirement Gifts For Women 2022 - Retired Gift...  B0B2WGL9ZW  Kitchen
# 521  Sister Gifts From Sister, Brother - Birthday G...  B0BC8WBYW7  Kitchen
# 522  Thank You Gifts Never Forget The Difference Th...  B0D5ZVC8SM     Home
#
#      Impressions: Impressions  Clicks: Clicks  Clicks: Click Rate (CTR)  \
# 518                        35               0                      0.00
# 519                        33               0                      0.00
# 520                        26               0                      0.00
# 521                        92               1                      1.25
# 522                        32               0                      0.00
#
#      Cart Adds: Cart Adds  Purchases: Purchases  \
# 518                     0                     0
# 519                     0                     0
# 520                     0                     0
# 521                     0                     0
# 522                     0                     0
#
#      Purchases: Search Traffic Sales  Purchases: Conversion Rate %  \
# 518                              0.0                           NaN
# 519                              0.0                           NaN
# 520                              0.0                           NaN
# 521                              0.0                           0.0
# 522                              0.0                           NaN
#
#     Reporting Date  Quarter
# 518     2025-06-30        2
# 519     2025-06-30        2
# 520     2025-06-30        2
# 521     2025-06-30        2
# 522     2025-06-30        2

# %%
scopes = ["https://www.googleapis.com/auth/spreadsheets", 
          "https://www.googleapis.com/auth/drive"]
creds = Credentials.from_service_account_file("/Users/thuytrinh/Downloads/new_credential.json", scopes=scopes)
client = gspread.authorize(creds)

# Mở Google Sheet
sheet_id = "1p3JWtN9HH1HxvARmx34Tmbt2iAjoYhK9fWIHgQr4PDE"

# Mở file Google Sheet (Spreadsheet object)
spreadsheet = client.open_by_key(sheet_id)
sheet1 = client.open_by_key(sheet_id).worksheet("BA_CA_2025")

set_with_dataframe(sheet1, final_df)

# %% [markdown]
# ## UK MARKET

# %%
import pandas as pd
import os
import sys
import re

import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from google.oauth2.service_account import Credentials

# %%
# Đường dẫn thư mục chứa các file CSV
folder_path = "UK/BA_UK/2024"

# Danh sách các file CSV
file_names = [
    "GB_Quarter 1_2024.csv",
    "GB_Quarter 2_2024.csv"
]

# Danh sách để chứa các dataframe sau khi đọc
dfs = []

for file in file_names:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path, skiprows=1)

    # Chuyển Reporting Date sang datetime
    df["Reporting Date"] = pd.to_datetime(df["Reporting Date"], errors="coerce")

    # Tính quarter từ Reporting Date
    df["quarter"] = df["Reporting Date"].dt.quarter

    dfs.append(df)

# Gộp tất cả lại
final_df = pd.concat(dfs, ignore_index=True)

# %%
scopes = ["https://www.googleapis.com/auth/spreadsheets", 
          "https://www.googleapis.com/auth/drive"]
creds = Credentials.from_service_account_file("/Users/thuytrinh/Downloads/new_credential.json", scopes=scopes)
client = gspread.authorize(creds)

# Mở Google Sheet
sheet_id = "1p3JWtN9HH1HxvARmx34Tmbt2iAjoYhK9fWIHgQr4PDE"

# Mở file Google Sheet (Spreadsheet object)
spreadsheet = client.open_by_key(sheet_id)
sheet1 = client.open_by_key(sheet_id).worksheet("BA_UK_2025")

set_with_dataframe(sheet1, final_df)
